# %% [markdown]
# Messungen an der FESTO anlage: 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# '1.22.3'

# %%
Messung1 = np.genfromtxt('Messung1.csv') 
Messung2 = np.genfromtxt('Messung2.csv') 
Messung3 = np.genfromtxt('Messung3.csv')
Messung4 = np.genfromtxt('Messung4.csv')
Messung5 = np.genfromtxt('Messung5.csv')
Messung6 = np.genfromtxt('Messung6.csv')
Messung7 = np.genfromtxt('Messung7.csv')
Messung = Messung4

plt.plot(Messung)
plt.show()
data_sliding_window = np.lib.stride_tricks.sliding_window_view(Messung, 125)
data_sliding_mean = np.array(np.mean(data_sliding_window, axis=1))
plt.plot(data_sliding_mean)
plt.show()
